# %%
import pandas as pd
df=pd.read_csv('run-of-river_production_load.csv')

# %%
feathures=df.shape[1]

# %%
df
# Out:
#                   Date_Time   Value        Date  precip_20  precip_40  \
# 0      2020-01-01T00:00:00Z  1986.0  2020-01-01        0.0        0.0
# 1      2020-01-01T00:15:00Z  1984.0  2020-01-01        0.0        0.0
# 2      2020-01-01T00:30:00Z  1934.0  2020-01-01        0.0        0.0
# 3      2020-01-01T00:45:00Z  1861.0  2020-01-01        0.0        0.0
# 4      2020-01-01T01:00:00Z  1882.0  2020-01-01        0.0        0.0
# ...                     ...     ...         ...        ...        ...
# 81787  2022-05-01T22:45:00Z  1580.0  2022-05-01        0.0        0.0
# 81788  2022-05-01T23:00:00Z  1560.0  2022-05-01        0.0        0.0
# 81789  2022-05-01T23:15:00Z  1559.0  2022-05-01        0.0        0.0
# 81790  2022-05-01T23:30:00Z  1560.0  2022-05-01        0.0        0.0
# 81791  2022-05-01T23:45:00Z  1559.0  2022-05-01        0.0        0.0
#
#        precip_75  precip_81  precip_104  precip_134  snow_depth_20  ...  \
# ...

# %%
newdf=pd.DataFrame()

# %%
newdf['unique_id']=df['Date']
newdf['ds']=df['Date_Time']
